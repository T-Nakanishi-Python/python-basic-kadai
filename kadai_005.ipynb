# %%
'''
上辺:10cm
下辺:20cm
高さ:5cm
の台形の面積を単位をcm^2で出力
'''

upper_side = 10
lower_side = 20
hight = 5
area = (upper_side + lower_side) * hight / 2

print(f"台形の面積は" + str(area) + "cm^2です。")
print(f"台形の面積は" + str((upper_side + lower_side) * hight / 2) + "cm^2です。")
# Out:
# 台形の面積は75.0cm^2です。
# 台形の面積は75.0cm^2です。
